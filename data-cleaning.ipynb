# %%
import pandas
import numpy as np
pandas.__version__
# Out:
# '1.2.4'

# %% [markdown]
# ## Read In Data

# %%
# read data from our csv
df = pandas.read_csv('2019-Present.csv')

# %%
df.head()
# Out:
#        Establishment ID Inspection Date Establishment Name  \
# 0             35-046524          1/8/19                565
# 1             35-046524          1/8/19                565
# 2             35-046524          1/8/19                565
# 3             35-046524          1/8/19                565
# 4             35-046524          1/8/19                565
# ...                 ...             ...                ...
# 158485        35-063899         8/22/23        ZULU GRILLE
# 158486        35-063899         8/22/23        ZULU GRILLE
# 158487        35-063899         8/22/23        ZULU GRILLE
# 158488        35-063899         8/22/23        ZULU GRILLE
# 158489        35-063899         8/22/23        ZULU GRILLE
#
#        Establishment Address Violation Code  \
# 0                565 E  2100         4.3.31
# 1                565 E  2100         4.3.56
# 2                565 E  2100         4.4.64
# 3                565 E  2100        4.4.76*
# 4                565 E  2100        4.4.82*
# ...                      ...            ...
# 158485      10709 S  REDWOOD        4.7.2**
# 158486      10709 S  REDWOOD         4.7.19
# 158487      10709 S  REDWOOD          4.1.3
# 158488      10709 S  REDWOOD  R392-510UICAA
# 158489      10709 S  REDWOOD     4.1.4 (ii)
#
#                                     Violation Description  \
# 0                  In-Use Utensils - Between-Use Storage.
# 1                                                 Thawing
# 2                                        Cutting Surfaces
# 3       Manual and Mechanical Warewashing Equipment-Ch...
# 4       Equipment, Food-Contact Surfaces, Nonfood-Cont...
# ...                                                   ...
# 158485                   Working Containers-Common Name**
# 158486                  Other Personal Care Items-Storage
# 158487                              Food Handler Training
# 158488                          Utah Indoor Clean Air Act
# 158489                   Food Safety Manager Registration
#
#         Violation Occurences
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
# ...                      ...
# 158485                   1.0
# 158486                   1.0
# 158487                   1.0
# 158488                   1.0
# 158489                   1.0
#
# [158490 rows x 7 columns]

# %%
# Fill in NaN values with "N/A"
df = df.fillna("N/A")

# %% [markdown]
# ## Add Columns to Identify Critical 1 and Critical 2 Violations

# %%
# Get the last character in Violation Code string, place into new column Critical Violation 1
# ref: https://stackoverflow.com/questions/52850192/python-extract-last-digit-of-a-string-from-a-pandas-column
df["Critical Violation 1"] = df["Violation Code"].str.strip().str[-1]
# If Critical Violation 1 contains "*", True, otherwise false
# ref: https://stackoverflow.com/questions/31511997/pandas-dataframe-replace-all-values-in-a-column-based-on-condition
df.loc[df["Critical Violation 1"] == "*", 'Critical Violation 1'] = True
df.loc[df["Critical Violation 1"] != True, 'Critical Violation 1'] = False

# Get the last two characters in Violation Code string, place into new column Critical Violation 2
df["Critical Violation 2"] = df["Violation Code"].str[-2:]
# If Critical Violation 2 contains "**", True, otherwise false
df.loc[df["Critical Violation 2"] == "**", 'Critical Violation 2'] = True
df.loc[df["Critical Violation 2"] != True, 'Critical Violation 2'] = False

# If both critical violation 1 and critical violation 2 are true, then it's just a critical 2 violation
df.loc[df['Critical Violation 2'] == True, "Critical Violation 1"] = False

# %%
# See the results
df.head()
# Out:
#        Establishment ID Inspection Date Establishment Name  \
# 0             35-046524          1/8/19                565
# 1             35-046524          1/8/19                565
# 2             35-046524          1/8/19                565
# 3             35-046524          1/8/19                565
# 4             35-046524          1/8/19                565
# ...                 ...             ...                ...
# 158485        35-063899         8/22/23        ZULU GRILLE
# 158486        35-063899         8/22/23        ZULU GRILLE
# 158487        35-063899         8/22/23        ZULU GRILLE
# 158488        35-063899         8/22/23        ZULU GRILLE
# 158489        35-063899         8/22/23        ZULU GRILLE
#
#        Establishment Address Violation Code  \
# 0                565 E  2100         4.3.31
# 1                565 E  2100         4.3.56
# 2                565 E  2100         4.4.64
# 3                565 E  2100        4.4.76*
# 4                565 E  2100        4.4.82*
# ...                      ...            ...
# 158485      10709 S  REDWOOD        4.7.2**
# 158486      10709 S  REDWOOD         4.7.19
# 158487      10709 S  REDWOOD          4.1.3
# 158488      10709 S  REDWOOD  R392-510UICAA
# 158489      10709 S  REDWOOD     4.1.4 (ii)
#
#                                     Violation Description  \
# 0                  In-Use Utensils - Between-Use Storage.
# 1                                                 Thawing
# 2                                        Cutting Surfaces
# 3       Manual and Mechanical Warewashing Equipment-Ch...
# 4       Equipment, Food-Contact Surfaces, Nonfood-Cont...
# ...                                                   ...
# 158485                   Working Containers-Common Name**
# 158486                  Other Personal Care Items-Storage
# 158487                              Food Handler Training
# 158488                          Utah Indoor Clean Air Act
# 158489                   Food Safety Manager Registration
#
#        Violation Occurences Critical Violation 1 Critical Violation 2
# 0                       1.0                False                False
# 1                       1.0                False                False
# 2                       1.0                False                False
# 3                       1.0                 True                False
# 4                       1.0                 True                False
# ...                     ...                  ...                  ...
# 158485                  1.0                False                 True
# 158486                  1.0                False                False
# 158487                  1.0                False                False
# 158488                  1.0                False                False
# 158489                  1.0                False                False
#
# [158490 rows x 9 columns]

# %% [markdown]
# ## Remove Numerical Identifiers from Restaurant Chains

# %%
# Split names that have "#" on "#" and keep only the first string
# ref: https://stackoverflow.com/questions/40705480/python-pandas-remove-everything-after-a-delimiter-in-a-string
df["Establishment Name"] = df["Establishment Name"].str.split('#').str[0]

# %%
# see the results, Subway for example
df.loc[df['Establishment Name'] == "SUBWAY"].head()
# Out:
#        Establishment ID Inspection Date Establishment Name  \
# 133048       35-0015876         11/5/19             SUBWAY
# 133049       35-0015876         11/5/19             SUBWAY
# 133050       35-0015876         11/5/19             SUBWAY
# 133051       35-0015876         11/5/19             SUBWAY
# 133052       35-0014316          8/9/19             SUBWAY
#
#        Establishment Address Violation Code  \
# 133048          1000 S  MAIN         4.4.62
# 133049          1000 S  MAIN         4.5.26
# 133050          1000 S  MAIN         4.6.49
# 133051          1000 S  MAIN         4.7.16
# 133052       11327 S  JORDAN         4.6.40
#
#                        Violation Description Violation Occurences  \
# 133048  Fixed Equipment-Elevation or Sealing                  1.0
# 133049           Using a Handwashing Sink.**                  1.0
# 133050      Using Dressing Rooms and Lockers                  1.0
# 133051              Restriction and Storage*                  1.0
# 133052         Repairing-Physical Facilities                  1.0
#
#        Critical Violation 1 Critical Violation 2  \
# 133048                False                False
# 133049                False                 True
# 133050                False                False
# 133051                 True                False
# 133052                False                False
#
#        Emergency Enforcement Violation Variance
# 133048                           False    False
# 133049                           False    False
# 133050                           False    False
# 133051                           False    False
# 133052                           False    False

# %% [markdown]
# ## Remove Non-Public Establishments

# %%
# define what strings to remove
to_remove = "SCHOOL|CENTER|CHILD|LIVING|CORRECTION|ARAMARK|HEALTH|CARE|JAIL|KIDS|ELEMENTARY|DETENTION|FOOD BANK|RECOVERY"
df = df[df["Establishment Name"].str.contains(to_remove)==False]

# %%
# see the results, for example, "ABOVE & BEYOND CHILDCARE" is gone
df.loc[df['Establishment Name'] == "ABOVE & BEYOND CHILDCARE"]
# Out:
# Empty DataFrame
# Columns: [Establishment ID, Inspection Date, Establishment Name, Establishment Address, Violation Code, Violation Description, Violation Occurences, Critical Violation 1, Critical Violation 2]
# Index: []

# %% [markdown]
# ## Add a Column Specifying 7.4.4 Emergency Enforcement Violations

# %%
# # Create a column called Emergency Enforcement Violation, populate with content of Violation Code
df["Emergency Enforcement Violation"] = df["Violation Code"]
# If Emergency Enforcement Violation contains 7.4.4 True, otherwise false
df.loc[df["Violation Code"].str.contains("7.4.4"), "Emergency Enforcement Violation"] = True
df.loc[df["Emergency Enforcement Violation"] != True, "Emergency Enforcement Violation"] = False
# Out:
# <ipython-input-11-fce06911f6a8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Emergency Enforcement Violation"] = df["Violation Code"]
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# see the results
df.loc[df['Violation Code'].str.contains("7.4.4")].head()
# Out:
#      Establishment ID Inspection Date  \
# 1951        35-045554          7/8/20
# 2820        35-041669         2/14/19
# 3205        35-060708          5/4/23
# 3744        35-042173          6/4/22
# 3962       35-0012368         1/19/23
#
#                              Establishment Name Establishment Address  \
# 1951  ALPINE MEADOW REAHABILITATION AND NURSING       2520 S  REDWOOD
# 2820          AMKHA MISKY PERUVIAN SPECIALTIES             215 S  800
# 3205                       ANTOJITOS EL COLOCHO          4219 W  3500
# 3744                            APOLLO BURGERS            940 W  1700
# 3962                       APPLE SPICE JUNCTION           6520 S  900
#
#      Violation Code                              Violation Description  \
# 1951     7.4.4 (ii)  Summary Permit Suspension - Imminent Health Ha...
# 2820     7.4.4 (ii)  Summary Permit Suspension - Imminent Health Ha...
# 3205     7.4.4 (ii)  Summary Permit Suspension - Imminent Health Ha...
# 3744     7.4.4 (ii)  Summary Permit Suspension - Imminent Health Ha...
# 3962     7.4.4 (ii)  Summary Permit Suspension - Imminent Health Ha...
#
#      Violation Occurences Critical Violation 1 Critical Violation 2  \
# 1951                  1.0                False                False
# 2820                  1.0                False                False
# 3205                  1.0                False                False
# 3744                  1.0                False                False
# 3962                  1.0                False                False
#
#      Emergency Enforcement Violation Variance
# 1951                            True    False
# 2820                            True    False
# 3205                            True    False
# 3744                            True    False
# 3962                            True    False

# %% [markdown]
# ## Remove Rows Containing Non-Violations or Undefined Violations

# %%
# define what strings to remove
to_remove = "R392-100: 5-202.11*|R392-510UICAA"
df = df[df["Violation Code"].str.contains(to_remove)==False]

# %%
# remove rows where violation code begins with 0
df = df[df["Violation Code"].str.startswith("0")==False]

# %%
# see the results, no violations that begin with 0
df.loc[df['Violation Code'].str.startswith("0")]
# Out:
# Empty DataFrame
# Columns: [Establishment ID, Inspection Date, Establishment Name, Establishment Address, Violation Code, Violation Description, Violation Occurences, Critical Violation 1, Critical Violation 2, Emergency Enforcement Violation]
# Index: []

# %%
# no violations using codes above
df.loc[df['Violation Code'].str.contains("R392")]
# Out:
# Empty DataFrame
# Columns: [Establishment ID, Inspection Date, Establishment Name, Establishment Address, Violation Code, Violation Description, Violation Occurences, Critical Violation 1, Critical Violation 2, Emergency Enforcement Violation]
# Index: []

# %% [markdown]
# ## Add a Column Specifying 7.4.2 Variances

# %%
# # Create a column called Emergency Enforcement Violation, populate with content of Violation Code
df["Variance"] = df["Violation Code"]
# If Emergency Enforcement Violation contains 7.4.4 True, otherwise false
df.loc[df["Violation Code"].str.contains("7.4.2"), "Variance"] = True
df.loc[df["Variance"] != True, "Variance"] = False

# %%
# see the results, variances are now labeled
df.loc[df['Violation Code'].str.contains("7.4.2")].head()
# Out:
#       Establishment ID Inspection Date                Establishment Name  \
# 19779        35-051497         6/11/19                          CAFE RIO
# 53075        35-063219          7/8/21  GOURMANDISE THE BAKERY DOG PATIO
# 55587        35-068491         1/11/23             HALL PASS - DOG PATIO
# 55859        35-055805        10/17/19               HANAPOKE SUGARHOUSE
# 67620        35-065809         1/27/23                        JUICE DRIP
#
#       Establishment Address Violation Code  \
# 19779          3585 S  8400    7.4.2 (iii)
# 53075            250 S  300     7.4.2 (ii)
# 55587     153 S  RIO GRANDE    7.4.2 (iii)
# 55859           675 E  2100     7.4.2 (ii)
# 67620        807 E  PIONEER      7.4.2 (i)
#
#                                    Violation Description Violation Occurences  \
# 19779               Conformance With Approved Procedures                  1.0
# 53075  Documentation of Proposed Variance and Justifi...                  1.0
# 55587               Conformance With Approved Procedures                  1.0
# 55859  Documentation of Proposed Variance and Justifi...                  1.0
# 67620                Variances Modifications and Waivers                  1.0
#
#       Critical Violation 1 Critical Violation 2  \
# 19779                False                False
# 53075                False                False
# 55587                False                False
# 55859                False                False
# 67620                False                False
#
#       Emergency Enforcement Violation Variance
# 19779                           False     True
# 53075                           False     True
# 55587                           False     True
# 55859                           False     True
# 67620                           False     True

# %% [markdown]
# ## Remove Astrisks from Violation Codes

# %%
# ref for removing characters:
# https://saturncloud.io/blog/what-is-the-best-way-to-remove-characters-from-a-string-in-pandas/
# https://pandas.pydata.org/docs/reference/api/pandas.Series.str.replace.html
df['Violation Code'] = df['Violation Code'].str.replace('*', '', regex=True)

# %%
# see results, astrisks are removed
df.head()
# Out:
#   Establishment ID Inspection Date Establishment Name Establishment Address  \
# 0        35-046524          1/8/19                565           565 E  2100
# 1        35-046524          1/8/19                565           565 E  2100
# 2        35-046524          1/8/19                565           565 E  2100
# 3        35-046524          1/8/19                565           565 E  2100
# 4        35-046524          1/8/19                565           565 E  2100
#
#   Violation Code                              Violation Description  \
# 0         4.3.31             In-Use Utensils - Between-Use Storage.
# 1         4.3.56                                            Thawing
# 2         4.4.64                                   Cutting Surfaces
# 3         4.4.76  Manual and Mechanical Warewashing Equipment-Ch...
# 4         4.4.82  Equipment, Food-Contact Surfaces, Nonfood-Cont...
#
#   Violation Occurences Critical Violation 1 Critical Violation 2  \
# 0                  1.0                False                False
# 1                  1.0                False                False
# 2                  1.0                False                False
# 3                  1.0                 True                False
# 4                  1.0                 True                False
#
#   Emergency Enforcement Violation Variance
# 0                           False    False
# 1                           False    False
# 2                           False    False
# 3                           False    False
# 4                           False    False

# %% [markdown]
# ## Save Data

# %%
# Save as json file
# ref: https://www.geeksforgeeks.org/exporting-pandas-dataframe-to-json-file/
df.to_json('data.json', orient = 'split', compression = 'infer', index = 'true')

# %%
# Save as csv
# ref: https://www.geeksforgeeks.org/saving-a-pandas-dataframe-as-a-csv/
df.to_csv('data.csv')
